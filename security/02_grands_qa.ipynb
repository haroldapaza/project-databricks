# %%
# %sql
GRANT USAGE ON CATALOG catalog_dev TO `qa-group`;
GRANT USE SCHEMA ON SCHEMA catalog_qa.bronze TO `qa-group`;
GRANT SELECT,CREATE,MODIFY ON SCHEMA catalog_qa.bronze TO `qa-group`;
GRANT SELECT,CREATE,MODIFY ON SCHEMA catalog_qa.silver TO `qa-group`;
GRANT SELECT,CREATE,MODIFY ON SCHEMA catalog_qa.gold  TO `qa-group`;
