# %%
# %sql
GRANT USAGE ON CATALOG catalog_dev TO `dev-group`;
GRANT USE SCHEMA ON SCHEMA catalog_dev.bronze TO `dev-group`;
GRANT SELECT,CREATE,MODIFY ON SCHEMA catalog_dev.bronze TO `dev-group`;
GRANT SELECT,CREATE,MODIFY ON SCHEMA catalog_dev.silver TO `dev-group`;
GRANT SELECT,CREATE,MODIFY ON SCHEMA catalog_dev.gold  TO `dev-group`;
